# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
import os 
from pygal import Bar,StackedBar
import seaborn as sns
# %matplotlib inline

# %%
clientes = pd.read_csv("CLIENTE.txt", sep="|")
clientes.head()
# Out:
#    ID                               NOMBRE SEXO      FH_NAC  ID_SUCURSAL
# 0   1               Elizabeth Ortiz Ortega    M  1974-11-08          100
# 1   2            Roberto Fernandez Vazquez    H  1971-01-20          491
# 2   3  María de los Ángeles Castro Ramirez    M  1976-10-28           43
# 3   4                  Rosa María Ruiz Gil    M  1976-01-25          166
# 4   5                   Eduardo Santos Gil    H  1982-05-31          447

# %%
cuenta = pd.read_csv("CUENTA.txt", sep='|')
cuenta.head()
# Out:
#    NUM_CUENTA  ID_CLIENTE TIPO_CUENTA  ID_PRODUCTO
# 0           1           1           C            1
# 1           2           6           C            2
# 2           3           7           C            3
# 3           4          11           C            4
# 4           5          12           C            1

# %%
estado = pd.read_csv("ESTADO.txt", sep='|')
print(estado.head())
# Out:
#    ID                NOMBRE CLAVE
# 0   1        Aguascalientes   AGS
# 1   2       Baja California    BC
# 2   3   Baja California Sur   BCS
# 3   4              Campeche   CAM
# 4   5  Coahuila de Zaragoza   COA

# %%
plastico = pd.read_csv('plastico.txt', sep='|')
plastico.tail()
# Out:
#                     PAN  ID_CUENTA
# 49455  4915569998344083      49456
# 49456  4915569998381170      49457
# 49457  4915569999202645      49458
# 49458  4915569999354229      49459
# 49459  4915569999471422      49460

# %%
producto = pd.read_csv('producto.txt', sep="|")
producto
# Out:
#    ID      NOMBRE
# 0   1  Std Credit
# 1   2  Gld Credit
# 2   3  Pla Credit
# 3   4  Inf Credit
# 4   5  Bsc Credit
# 5   6   Bsc Debit
# 6   7   Prm Debit

# %%
sucursal = pd.read_csv('sucursal.txt', sep="|")
sucursal
# Out:
#       ID  ID_ESTADO
# 0      1         19
# 1      2         15
# 2      3         28
# 3      4         29
# 4      5         13
# 5      6         14
# 6      7         10
# 7      8         28
# 8      9         11
# 9     10         24
# 10    11          5
# 11    12         11
# 12    13         14
# 13    14         30
# 14    15         32
# 15    16          9
# 16    17         19
# 17    18          7
# 18    19         20
# 19    20          1
# 20    21         29
# 21    22         23
# 22    23          5
# 23    24         18
# 24    25         30
# 25    26          2
# 26    27         11
# 27    28         18
# 28    29         21
# 29    30         21
# ..   ...        ...
# 639  640          1
# 640  641         19
# 641  642         30
# 642  643          4
# 643  644         32
# 644  645          4
# 645  646         13
# 646  647          5
# 647  648         24
# 648  649         24
# 649  650         32
# 650  651         24
# 651  652         32
# ...

# %%
transaccion = pd.read_csv('transaccion.txt', sep='|')
transaccion
# Out:
#              ID    CVEAUT       FECHA              HORA    MONTO ESTATUS  \
# 0             1  56774696  2014-11-15  12:54:58.0000000   310.03       A
# 1             2  10267087  2016-05-26  10:00:55.0000000  2968.16       A
# 2             3  29831751  2016-06-23  07:07:51.0000000  1009.01       A
# 3             4  83467869  2014-12-07  07:51:44.0000000   714.91       A
# 4             5  49039947  2015-10-09  03:29:18.0000000   629.97       A
# 5             6  79499628  2014-01-28  09:04:29.0000000  2324.47       A
# 6             7  30901681  2014-03-21  05:09:03.0000000   305.63       A
# 7             8  54984612  2016-05-07  09:01:45.0000000  1652.05       A
# 8             9  65373521  2014-09-04  06:39:47.0000000  1395.50       A
# 9            10  87121042  2015-09-25  06:42:15.0000000   749.34       A
# 10           11   7836774  2016-02-27  11:58:43.0000000  1392.02       A
# 11           12  24842100  2014-01-17  06:28:53.0000000  1356.06       A
# ...

# %%
clientes[["ID", "NOMBRE"]].groupby("ID").sum()
# Out:
#                                     NOMBRE
# ID
# 1                   Elizabeth Ortiz Ortega
# 2                Roberto Fernandez Vazquez
# 3      María de los Ángeles Castro Ramirez
# 4                      Rosa María Ruiz Gil
# 5                       Eduardo Santos Gil
# 6                    Antonio Ramirez Gomez
# 7                    Roberto Perez Sanchez
# 8       María de los Ángeles Santos Castro
# 9                   Alejandro Blanco Gomez
# 10                  Javier Ortega Gonzalez
# 11                        Jorge Gil Torres
# 12                   Josefina Martinez Gil
# 13                   Adriana Flores Alonso
# 14                Francisco Morales Santos
# 15               José Antonio Lopez Garcia
# 16               Ricardo Ramirez Fernandez
# 17                     Silvia Alonso Munoz
# 18                    Yolanda Blanco Ortiz
# 19            María Guadalupe Munoz Alonso
# 20                   Manuel Moreno Jimenez
# 21                   Javier Alonso Vazquez
# ...

# %%
print(producto.info(), sucursal.info(), cuenta.info(), plastico.info(), estado.info(), transaccion.info())
#producto[["ID", "NOMBRE"]].groupby("ID").sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 2 columns):
# ID        7 non-null int64
# NOMBRE    7 non-null object
# dtypes: int64(1), object(1)
# memory usage: 192.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 669 entries, 0 to 668
# Data columns (total 2 columns):
# ID           669 non-null int64
# ID_ESTADO    669 non-null int64
# dtypes: int64(2)
# memory usage: 10.5 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49460 entries, 0 to 49459
# Data columns (total 4 columns):
# NUM_CUENTA     49460 non-null int64
# ID_CLIENTE     49460 non-null int64
# TIPO_CUENTA    49460 non-null object
# ID_PRODUCTO    49460 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49460 entries, 0 to 49459
# Data columns (total 2 columns):
# PAN          49460 non-null int64
# ID_CUENTA    49460 non-null int64
# dtypes: int64(2)
# memory usage: 772.9 KB
# ...

# %%
transaccion = pd.read_csv('transaccion.txt', sep='|')
transaccion.MONTO.mean()
# Out:
# 958.37316390000024

# %%
transaccion = pd.read_csv('transaccion.txt', sep='|')
transaccion.groupby('ESTATUS').MONTO.mean()
# Out:
# ESTATUS
# A    958.36576
# R    958.48865
# Name: MONTO, dtype: float64

# %%
clientes = pd.read_csv("CLIENTE.txt", sep="|")
clientes.NOMBRE.str.contains('Felipe')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 44558    False
# 44559    False
# 44560    False
# 44561    False
# 44562    False
# 44563    False
# 44564    False
# 44565    False
# 44566    False
# 44567    False
# 44568    False
# 44569    False
# 44570    False
# 44571    False
# 44572    False
# 44573    False
# 44574    False
# 44575    False
# 44576    False
# 44577    False
# 44578    False
# 44579    False
# 44580    False
# 44581    False
# 44582    False
# 44583    False
# 44584    False
# ...

# %%
clientes = pd.read_csv("CLIENTE.txt", sep="|")
clientes.NOMBRE.str.contains('Roberto')
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4        False
# 5        False
# 6         True
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 44558    False
# 44559    False
# 44560    False
# 44561    False
# 44562    False
# 44563    False
# 44564    False
# 44565    False
# 44566    False
# 44567    False
# 44568    False
# 44569    False
# 44570     True
# 44571    False
# 44572    False
# 44573    False
# 44574    False
# 44575    False
# 44576    False
# 44577    False
# 44578    False
# 44579    False
# 44580    False
# 44581    False
# 44582    False
# 44583    False
# 44584    False
# ...

# %%
transaccion = pd.read_csv('transaccion.txt', sep='|')
plastico = pd.read_csv('plastico.txt', sep='|')
pan = pd.merge(transaccion, plastico, on='PAN')
pan
# Out:
#             ID    CVEAUT       FECHA              HORA    MONTO ESTATUS  \
# 0            1  56774696  2014-11-15  12:54:58.0000000   310.03       A
# 1        19407  61380887  2014-07-03  11:25:22.0000000   799.66       A
# 2        53529  49460619  2016-04-16  09:01:23.0000000  1634.77       A
# 3       116741   5098731  2015-01-22  05:54:42.0000000   827.56       A
# 4       132747  74101866  2014-10-27  15:50:30.0000000   484.85       R
# 5       174914  12308301  2014-02-12  06:27:38.0000000   954.78       A
# 6       233586  92925127  2014-11-05  03:48:01.0000000  2271.60       A
# 7       348874  88890794  2014-12-11  06:41:42.0000000   972.33       R
# 8       476740  14465186  2015-04-25  07:07:54.0000000   909.84       A
# 9       496330  70314504  2014-06-30  06:45:22.0000000   454.58       A
# 10      656692  18297913  2014-11-22  05:15:37.0000000  1705.16       A
# 11      681245  12860479  2015-04-08  04:03:49.0000000   514.97       A
# ...

# %%
sucursal = pd.read_csv('sucursal.txt', sep="|")
estado = pd.read_csv("ESTADO.txt", sep='|')
id1 = pd.merge(sucursal, estado, on='ID')
id1
# Out:
#     ID  ID_ESTADO                           NOMBRE CLAVE
# 0    1         19                   Aguascalientes   AGS
# 1    2         15                  Baja California    BC
# 2    3         28              Baja California Sur   BCS
# 3    4         29                         Campeche   CAM
# 4    5         13             Coahuila de Zaragoza   COA
# 5    6         14                           Colima   COL
# 6    7         10                          Chiapas  CHIS
# 7    8         28                        Chihuahua   CHI
# 8    9         11                 Distrito Federal   CDM
# 9   10         24                          Durango   DGO
# 10  11          5                       Guanajuato   GUA
# 11  12         11                         Guerrero   GUE
# 12  13         14                          Hidalgo    HI
# 13  14         30                          Jalisco   JAL
# 14  15         32                           México   MEX
# ...

# %%
clientes = pd.read_csv("CLIENTE.txt", sep="|")
clientes.iloc[:, 0:5]
# Out:
#           ID                               NOMBRE SEXO      FH_NAC  \
# 0          1               Elizabeth Ortiz Ortega    M  1974-11-08
# 1          2            Roberto Fernandez Vazquez    H  1971-01-20
# 2          3  María de los Ángeles Castro Ramirez    M  1976-10-28
# 3          4                  Rosa María Ruiz Gil    M  1976-01-25
# 4          5                   Eduardo Santos Gil    H  1982-05-31
# 5          6                Antonio Ramirez Gomez    H  1973-08-30
# 6          7                Roberto Perez Sanchez    H  1972-03-05
# 7          8   María de los Ángeles Santos Castro    M  1980-05-09
# 8          9               Alejandro Blanco Gomez    H  1989-08-06
# 9         10               Javier Ortega Gonzalez    H  1976-07-15
# 10        11                     Jorge Gil Torres    H  1979-12-30
# 11        12                Josefina Martinez Gil    M  1971-05-29
# 12        13                Adriana Flores Alonso    M  1983-03-03
# ...

# %%
cuenta = pd.read_csv("CUENTA.txt", sep='|')
cuenta.pivot(index='NUM_CUENTA', columns='ID_PRODUCTO')
# Out:
#             ID_CLIENTE                                         TIPO_CUENTA  \
# ID_PRODUCTO          1     2     3     4   5        6        7           1
# NUM_CUENTA
# 1                  1.0   NaN   NaN   NaN NaN      NaN      NaN           C
# 2                  NaN   6.0   NaN   NaN NaN      NaN      NaN        None
# 3                  NaN   NaN   7.0   NaN NaN      NaN      NaN        None
# 4                  NaN   NaN   NaN  11.0 NaN      NaN      NaN        None
# 5                 12.0   NaN   NaN   NaN NaN      NaN      NaN           C
# 6                  NaN  15.0   NaN   NaN NaN      NaN      NaN        None
# 7                 16.0   NaN   NaN   NaN NaN      NaN      NaN           C
# 8                  NaN   NaN  22.0   NaN NaN      NaN      NaN        None
# 9                 24.0   NaN   NaN   NaN NaN      NaN      NaN           C
# 10                 NaN   NaN   NaN  25.0 NaN      NaN      NaN        None
# ...

# %%
producto = pd.read_csv('producto.txt', sep="|")
plt.plot(producto)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-934be6271179> in <module>()
#       1 producto = pd.read_csv('producto.txt', sep="|")
# ----> 2 plt.plot(producto)
#
# ~/.local/lib/python3.5/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3238                       mplDeprecation)
#    3239     try:
# -> 3240         ret = ax.plot(*args, **kwargs)
#    3241     finally:
#    3242         ax._hold = washold
#
# ~/.local/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1708                     warnings.warn(msg % (label_namer, func.__name__),
#    1709                                   RuntimeWarning, stacklevel=2)
# -> 1710             return func(ax, *args, **kwargs)
#    1711         pre_doc = inner.__doc__
#    1712         if pre_doc is None:
#
# ...
